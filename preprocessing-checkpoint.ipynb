# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
dataframe=pd.read_csv('hypothyroid.csv')

# %%
dataframe
# Out:
#       age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0      41   F            f                  f                         f    f
# 1      23   F            f                  f                         f    f
# 2      46   M            f                  f                         f    f
# 3      70   F            t                  f                         f    f
# 4      70   F            f                  f                         f    f
# ...   ...  ..          ...                ...                       ...  ...
# 3767   30   F            f                  f                         f    f
# 3768   68   F            f                  f                         f    f
# 3769   74   F            f                  f                         f    f
# 3770   72   M            f                  f                         f    f
# 3771   64   F            f                  f                         f    f
#
# ...

# %%
dataframe.head(5)
# Out:
#    age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0   41   F            f                  f                         f    f
# 1   23   F            f                  f                         f    f
# 2   46   M            f                  f                         f    f
# 3   70   F            t                  f                         f    f
# 4   70   F            f                  f                         f    f
#
#   pregnant thyroid surgery I131 treatment query hypothyroid  ... TT4 measured  \
# 0        f               f              f                 f  ...            t
# 1        f               f              f                 f  ...            t
# 2        f               f              f                 f  ...            t
# 3        f               f              f                 f  ...            t
# 4        f               f              f                 f  ...            t
#
# ...

# %%
dataframe.tail(10)
# Out:
#       age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 3762   61   M            f                  f                         f    f
# 3763   41   F            f                  f                         f    f
# 3764   54   M            f                  f                         f    f
# 3765   73   F            t                  f                         f    f
# 3766   19   F            f                  f                         f    f
# 3767   30   F            f                  f                         f    f
# 3768   68   F            f                  f                         f    f
# 3769   74   F            f                  f                         f    f
# 3770   72   M            f                  f                         f    f
# 3771   64   F            f                  f                         f    f
#
#      pregnant thyroid surgery I131 treatment query hypothyroid  ...  \
# ...

# %%
dataframe.sample(5)
# Out:
#       age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 806    64   M            f                  f                         f    f
# 721    37   F            f                  f                         f    f
# 1601   68   F            f                  f                         f    f
# 1461   63   F            f                  f                         f    f
# 1972   62   M            f                  f                         f    t
#
#      pregnant thyroid surgery I131 treatment query hypothyroid  ...  \
# 806         f               f              f                 f  ...
# 721         f               f              f                 f  ...
# 1601        f               f              f                 f  ...
# 1461        f               f              f                 f  ...
# 1972        f               f              f                 f  ...
#
#      TT4 measured  TT4 T4U measured   T4U FTI measured  FTI TBG measured TBG  \
# ...

# %%
dataframe.size
# Out:
# 113160

# %%
dataframe.shape
# Out:
# (3772, 30)

# %%
dataframe.describe(include='all')
# Out:
#                 age   sex on thyroxine query on thyroxine  \
# count   3772.000000  3772         3772               3772
# unique          NaN     3            2                  2
# top             NaN     F            f                  f
# freq            NaN  2480         3308               3722
# mean      51.738070   NaN          NaN                NaN
# std       20.082746   NaN          NaN                NaN
# min        1.000000   NaN          NaN                NaN
# 25%       36.000000   NaN          NaN                NaN
# 50%       54.000000   NaN          NaN                NaN
# 75%       67.000000   NaN          NaN                NaN
# max      455.000000   NaN          NaN                NaN
#
#        on antithyroid medication  sick pregnant thyroid surgery  \
# count                       3772  3772     3772            3772
# unique                         2     2        2               2
# top                            f     f        f               f
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        3772 non-null   int64
#  1   sex                        3772 non-null   object
#  2   on thyroxine               3772 non-null   object
#  3   query on thyroxine         3772 non-null   object
#  4   on antithyroid medication  3772 non-null   object
#  5   sick                       3772 non-null   object
#  6   pregnant                   3772 non-null   object
#  7   thyroid surgery            3772 non-null   object
#  8   I131 treatment             3772 non-null   object
#  9   query hypothyroid          3772 non-null   object
#  10  query hyperthyroid         3772 non-null   object
#  11  lithium                    3772 non-null   object
#  12  goitre                     3772 non-null   object
# ...

# %%
dataframe=dataframe.drop_duplicates()

# %%
dataframe['age'].unique
# Out:
# <bound method Series.unique of 0       41
# 1       23
# 2       46
# 3       70
# 4       70
#         ..
# 3767    30
# 3768    68
# 3769    74
# 3770    72
# 3771    64
# Name: age, Length: 3711, dtype: int64>

# %%
dataframe.isnull().sum()
# Out:
# age                          0
# sex                          0
# on thyroxine                 0
# query on thyroxine           0
# on antithyroid medication    0
# sick                         0
# pregnant                     0
# thyroid surgery              0
# I131 treatment               0
# query hypothyroid            0
# query hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH measured                 0
# TSH                          0
# T3 measured                  0
# T3                           0
# TT4 measured                 0
# TT4                          0
# T4U measured                 0
# T4U                          0
# FTI measured                 0
# FTI                          0
# TBG measured                 0
# TBG                          0
# referral source              0
# binaryClass                  0
# ...

# %%
drop_dataframe=dataframe.copy()
drop_dataframe.shape
# Out:
# (3711, 30)

# %%
drop_dataframe=dataframe.dropna()

# %%
drop_dataframe.shape
# Out:
# (3711, 30)

# %%
drop_dataframe.isnull().sum()
# Out:
# age                          0
# sex                          0
# on thyroxine                 0
# query on thyroxine           0
# on antithyroid medication    0
# sick                         0
# pregnant                     0
# thyroid surgery              0
# I131 treatment               0
# query hypothyroid            0
# query hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH measured                 0
# TSH                          0
# T3 measured                  0
# T3                           0
# TT4 measured                 0
# TT4                          0
# T4U measured                 0
# T4U                          0
# FTI measured                 0
# FTI                          0
# TBG measured                 0
# TBG                          0
# referral source              0
# binaryClass                  0
# ...

# %%
replace_dataframe=dataframe.copy()
replace_dataframe.fillna(0)
# Out:
#       age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0      41   F            f                  f                         f    f
# 1      23   F            f                  f                         f    f
# 2      46   M            f                  f                         f    f
# 3      70   F            t                  f                         f    f
# 4      70   F            f                  f                         f    f
# ...   ...  ..          ...                ...                       ...  ...
# 3767   30   F            f                  f                         f    f
# 3768   68   F            f                  f                         f    f
# 3769   74   F            f                  f                         f    f
# 3770   72   M            f                  f                         f    f
# 3771   64   F            f                  f                         f    f
#
# ...

# %%
replace_dataframe.isnull().sum()
# Out:
# age                          0
# sex                          0
# on thyroxine                 0
# query on thyroxine           0
# on antithyroid medication    0
# sick                         0
# pregnant                     0
# thyroid surgery              0
# I131 treatment               0
# query hypothyroid            0
# query hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH measured                 0
# TSH                          0
# T3 measured                  0
# T3                           0
# TT4 measured                 0
# TT4                          0
# T4U measured                 0
# T4U                          0
# FTI measured                 0
# FTI                          0
# TBG measured                 0
# TBG                          0
# referral source              0
# binaryClass                  0
# ...

# %%
plt.figure(figsize=(50,9))

sns.barplot(dataframe,x='age',y='age')
# Out:
# <Axes: xlabel='age', ylabel='age'>

# %%
dataframe['age'].max()
# Out:
# 455

# %%
dataframe['age'].min()
# Out:
# 1

# %%
sns.displot(dataframe['age'],kind='hist')

# %%
sns.histplot(dataframe['age'],binwidth=2,color='r')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(dataframe['age'],color='r')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.boxplot(x=dataframe['age'])
# Out:
# <Axes: xlabel='age'>

# %%
dataframe['age'].describe()
# Out:
# count    3711.000000
# mean       51.862571
# std        20.121316
# min         1.000000
# 25%        36.000000
# 50%        54.000000
# 75%        67.000000
# max       455.000000
# Name: age, dtype: float64

# %%
dataframe['age'].quantile(0)
# Out:
# 1.0

# %%
dataframe['age'].quantile(0.25)
# Out:
# 36.0

# %%
dataframe['age'].quantile(0.50)
# Out:
# 54.0

# %%
dataframe['age'].quantile(0.75)
# Out:
# 67.0

# %%
dataframe['age'].quantile(1)
# Out:
# 455.0

# %%
q1=dataframe['age'].quantile(0.25)
q3=dataframe['age'].quantile(0.75)

# %%
IQR = q3-q1

# %%
IQR
# Out:
# 31.0

# %%
lower_range=q1-1.5*IQR

# %%
lower_range
# Out:
# -10.5

# %%
upper_range=q3+1.5*IQR

# %%
upper_range
# Out:
# 113.5

# %%
trimming_data=dataframe[(dataframe['age']>lower_range) & (dataframe['age']<upper_range) ]

# %%
trimming_data
# Out:
#       age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0      41   F            f                  f                         f    f
# 1      23   F            f                  f                         f    f
# 2      46   M            f                  f                         f    f
# 3      70   F            t                  f                         f    f
# 4      70   F            f                  f                         f    f
# ...   ...  ..          ...                ...                       ...  ...
# 3767   30   F            f                  f                         f    f
# 3768   68   F            f                  f                         f    f
# 3769   74   F            f                  f                         f    f
# 3770   72   M            f                  f                         f    f
# 3771   64   F            f                  f                         f    f
#
# ...

# %%
sns.kdeplot(trimming_data['age'],color='r')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(trimming_data['age'],binwidth=5,color='r')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x=trimming_data['age'])
# Out:
# <Axes: xlabel='age'>

# %%
lower_range
# Out:
# -10.5

# %%
capping_range=dataframe.copy()

# %%
capping_range['age']=np.where(capping_range['age'] < lower_range,lower_range,
          np.where(capping_range['age'] > upper_range,upper_range,
                   capping_range['age']))

# %%
capping_range['age'].min()
# Out:
# 1.0

# %%
capping_range['age'].max()
# Out:
# 113.5

# %%
capping_range['age'].mean()
# Out:
# 51.77054702236594

# %%
capping_range['age']
# Out:
# 0       41.0
# 1       23.0
# 2       46.0
# 3       70.0
# 4       70.0
#         ...
# 3767    30.0
# 3768    68.0
# 3769    74.0
# 3770    72.0
# 3771    64.0
# Name: age, Length: 3711, dtype: float64

# %%
sns.kdeplot(capping_range['age'],color='r')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.boxplot(x=capping_range['age'])
# Out:
# <Axes: xlabel='age'>

# %%
sns.histplot(capping_range['age'],binwidth=5,color='r')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
capping_median=dataframe.copy()

# %%
capping_median
# Out:
#       age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0      41   F            f                  f                         f    f
# 1      23   F            f                  f                         f    f
# 2      46   M            f                  f                         f    f
# 3      70   F            t                  f                         f    f
# 4      70   F            f                  f                         f    f
# ...   ...  ..          ...                ...                       ...  ...
# 3767   30   F            f                  f                         f    f
# 3768   68   F            f                  f                         f    f
# 3769   74   F            f                  f                         f    f
# 3770   72   M            f                  f                         f    f
# 3771   64   F            f                  f                         f    f
#
# ...

# %%
median=capping_median['age'].median()
median
# Out:
# 54.0

# %%
capping_median['age']=np.where(capping_median['age'] < lower_range,median,
          np.where(capping_median['age'] > upper_range,median,
                   capping_median['age'])
                  )

# %%
sns.kdeplot(capping_median['age'],color='r')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(capping_median['age'],binwidth=10,color='r')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x=capping_median['age'])
# Out:
# <Axes: xlabel='age'>

# %%
capping_median['age'].min()
# Out:
# 1.0

# %%
capping_median['age'].max()
# Out:
# 94.0

# %%
capping_median
# Out:
#        age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0     41.0   F            f                  f                         f    f
# 1     23.0   F            f                  f                         f    f
# 2     46.0   M            f                  f                         f    f
# 3     70.0   F            t                  f                         f    f
# 4     70.0   F            f                  f                         f    f
# ...    ...  ..          ...                ...                       ...  ...
# 3767  30.0   F            f                  f                         f    f
# 3768  68.0   F            f                  f                         f    f
# 3769  74.0   F            f                  f                         f    f
# 3770  72.0   M            f                  f                         f    f
# 3771  64.0   F            f                  f                         f    f
#
# ...

# %%
std_dataframe=dataframe.copy()
lower_limit = std_dataframe["age"].mean() - (3 * std_dataframe["age"].std())
upper_limit = std_dataframe["age"].mean() + (3 * std_dataframe["age"].std())

print(lower_limit)
print(upper_limit)
# Out:
# -8.501377555378973
# 112.2265190266805
